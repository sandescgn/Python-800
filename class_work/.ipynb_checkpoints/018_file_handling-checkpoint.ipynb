# %%
f = open('hello.txt')
f.read()
# Out:
# 'hello world. Welcome to python course.\nWe are reading file handling.'

# %%
f = open('hello.txt')
print(f.read())
# Out:
# hello world. Welcome to python course.
# We are reading file handling.

# %%
f = open('hello.txt', 'r') # open in read mode
print(f.read())
# Out:
# hello world. Welcome to python course.
# We are reading file handling.

# %%
f = open('hello1.txt', 'w') # open in write mode
f.write("Hello1 file. THis is test file.")
# Out:
# 31

# %%
f = open('hello2.txt', 'w') # open in write mode
f.write("Hello2 file. THis is test file.")
f.close()

# %%
f = open('hello_xyz.txt')
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 f = open('hello_xyz.txt')
#       2 print(f.read())
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hello_xyz.txt'

# %%
f = open('hello.txt', 'rt') # open => read  in text mode
print(f.read())
# Out:
# hello world. Welcome to python course.
# We are reading file handling.

# %%
f = open('python.jpeg', 'rt') # open => read  in text mode
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 2
#       1 f = open('python.jpeg', 'rt') # open => read  in text mode
# ----> 2 print(f.read())
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
f = open('python.jpeg', 'rb') # open => read  in text mode
print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x10\x0e\x11\x0f\x10\x10\r\x10\x0f\x0f\x0e\x10\x0e\r\x11\x0f\x10\r\x11\r\r\r\x0e\x14\x12\x16\x18\x16\x12\x13\x13\x18\x1e4!\x18\x1b1\'\x13\x15!2!&50./.\x17\x1f383,7(-:0\x01\n\n\n\x0e\r\x0e\x1a\x10\x10\x1a+" &/+.2--70+2/--72------7-+--------.//-/-+-------+-+-\xff\xc0\x00\x11\x08\x00\xc8\x00\xc8\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x01\x01\x00\x02\x03\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x01\x05\x03\x06\x07\x04\xff\xc4\x00?\x10\x00\x02\x01\x02\x02\x04\t\t\x07\x03\x05\x00\x00\x00\x00\x00\x00\x01\x02\x03\x11\x04\x05\x06\x12!1\x13AQTaq\x81\x91\xb1\x07\x152Rb\x93\xa1\xc1\xd2\x14$Bs\x92\xb2\xd1"4r\x163Ct\xf0\xff\xc4\x00\x1a\x01\x01\x01\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x04\x05\x03\x06\xff\xc4\x003\x11\x01\x00\x01\x03\x01\x05\x05\x07\x04\x02\x03\x00\x00\x00\x00\x00\x00\x01\x02\x03\x11\x04\x05\x12!1Q\x142Aq\xb1\x13\x15"3R\x8
# ...

# %%
f = open('hello2.txt', 'w') # open in write mode => replace the whole content
f.write("hello word")
f.close()

# %%
f = open('hello2.txt', 'a') # open in append mode # insert at end of the file
f.write("hello word")
f.close()

# %%
f = open('hello2.txt', 'a') # open in append mode # insert at end of the file
f.write("hello word")
x = 1 / 0
f.close()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 f = open('hello2.txt', 'a') # open in append mode # insert at end of the file
#       2 f.write("hello word")
# ----> 3 x = 1 / 0
#       4 f.close()
#
# ZeroDivisionError: division by zero

# %%
# exceptional handling
